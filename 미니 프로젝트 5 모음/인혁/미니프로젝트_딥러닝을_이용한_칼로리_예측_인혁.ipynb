# %%
! pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 8.1 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (2.0.9)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.3-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 25.4 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.3 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1

# %%
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier
import warnings 
import optuna
from optuna import Trial, visualization
from optuna.samplers import TPESampler
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/미니 프로젝트/미니 프로젝트5/칼로리 데이터셋.zip'
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Colab Notebooks/미니 프로젝트/미니 프로젝트5/칼로리 데이터셋.zip, /content/drive/MyDrive/Colab Notebooks/미니 프로젝트/미니 프로젝트5/칼로리 데이터셋.zip.zip or /content/drive/MyDrive/Colab Notebooks/미니 프로젝트/미니 프로젝트5/칼로리 데이터셋.zip.ZIP.

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니 프로젝트/미니 프로젝트5/open 2/train.csv',index_col="ID")
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니 프로젝트/미니 프로젝트5/open 2/test.csv',index_col="ID")
sample_submission = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/미니 프로젝트/미니 프로젝트5/open 2/sample_submission.csv',index_col="ID")

# %%
train['Height(cm)'] = train['Height(Feet)'] * 30.48 + train['Height(Remainder_Inches)']*2.54
test['Height(cm)'] = test['Height(Feet)'] * 30.48 + test['Height(Remainder_Inches)']*2.54

# %%
# 기존 ft, inch column은 삭제 
train = train.drop(columns=['Height(Feet)','Height(Remainder_Inches)'])
test = test.drop(columns=['Height(Feet)','Height(Remainder_Inches)'])

# %%
# 몸무게를 kg   변경
train['Weight(kg)'] = train['Weight(lb)'] * 0.45359237
test['Weight(kg)'] = test['Weight(lb)'] * 0.45359237

# %%
# 이전 데이터 삭제 
train = train.drop(columns=['Weight(lb)'])
test = test.drop(columns=['Weight(lb)'])

# %%
train['BMI'] = train['Weight(kg)'] / ((train['Height(cm)'] / 100) ** 2)
test['BMI'] = test['Weight(kg)'] / ((test['Height(cm)'] / 100) ** 2)

# %%
train=pd.get_dummies(train)
test=pd.get_dummies(test)

# %%
plt.figure(figsize = (20,6))
sns.boxplot(data = train)
# Out:
# <Axes: >

# %%
train.head()
# Out:
#             Exercise_Duration  Body_Temperature(F)    BPM  Age  \
# ID
# TRAIN_0000               26.0                105.6  107.0   45
# TRAIN_0001                7.0                103.3   88.0   50
# TRAIN_0002                7.0                103.3   86.0   29
# TRAIN_0003               17.0                104.0   99.0   33
# TRAIN_0004                9.0                102.7   88.0   38
#
#             Calories_Burned  Height(cm)  Weight(kg)        BMI  \
# ID
# TRAIN_0000            166.0      175.26   69.989303  22.785893
# TRAIN_0001             33.0      198.12  102.012924  25.989538
# TRAIN_0002             23.0      190.50   99.019214  27.285349
# TRAIN_0003             91.0      167.64   66.995593  23.839159
# TRAIN_0004             32.0      177.80   77.019984  24.363513
#
#             Weight_Status_Normal Weight  Weight_Status_Obese  \
# ID
# TRAIN_0000                            1                    0
# TRAIN_0001                            0                    0
# TRAIN_0002                            0                    0
# TRAIN_0003                            1                    0
# TRAIN_0004                            1                    0
#
#             Weight_Status_Overweight  Gender_F  Gender_M
# ID
# TRAIN_0000                         0         1         0
# TRAIN_0001                         1         0         1
# TRAIN_0002                         1         0         1
# TRAIN_0003                         0         1         0
# TRAIN_0004                         0         0         1

# %%
# Out:
# Index([], dtype='object')

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7500 entries, TRAIN_0000 to TRAIN_7499
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Exercise_Duration            7500 non-null   float64
#  1   Body_Temperature(F)          7500 non-null   float64
#  2   BPM                          7500 non-null   float64
#  3   Age                          7500 non-null   int64
#  4   Calories_Burned              7500 non-null   float64
#  5   Height(cm)                   7500 non-null   float64
#  6   Weight(kg)                   7500 non-null   float64
#  7   BMI                          7500 non-null   float64
#  8   Weight_Status_Normal Weight  7500 non-null   uint8
#  9   Weight_Status_Obese          7500 non-null   uint8
#  10  Weight_Status_Overweight     7500 non-null   uint8
#  11  Gender_F                     7500 non-null   uint8
#  12  Gender_M                     7500 non-null   uint8
# dtypes: float64(7), int64(1), uint8(5)
# memory usage: 822.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 7500 entries, TEST_0000 to TEST_7499
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Exercise_Duration            7500 non-null   float64
#  1   Body_Temperature(F)          7500 non-null   float64
#  2   BPM                          7500 non-null   float64
#  3   Age                          7500 non-null   int64
#  4   Height(cm)                   7500 non-null   float64
#  5   Weight(kg)                   7500 non-null   float64
#  6   BMI                          7500 non-null   float64
#  7   Weight_Status_Normal Weight  7500 non-null   uint8
#  8   Weight_Status_Obese          7500 non-null   uint8
#  9   Weight_Status_Overweight     7500 non-null   uint8
#  10  Gender_F                     7500 non-null   uint8
#  11  Gender_M                     7500 non-null   uint8
# dtypes: float64(6), int64(1), uint8(5)
# memory usage: 505.4+ KB
# (None, None)

# %% [markdown]
# # X, y 만들기

# %%
X = train.drop(columns="Calories_Burned")
y = train["Calories_Burned"]

X.shape, y.shape
# Out:
# ((7500, 12), (7500,))

# %%
# train_test_split을 이용해 X, y 값을 X_train, X_valid, y_train, y_valid 으로 나눠줍니다.
# Hold-out-valiation을 위해 train, valid 세트로 나누기
# test_size=0.1 => 이름은 test지만 train으로 나눠주었기 때문에 valid 사이즈를 지정한 것입니다.
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(
    X, y, test_size=0.1, random_state=42)

X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((6750, 12), (750, 12), (6750,), (750,))

# %%
X_test = test
X_test.shape
# Out:
# (7500, 12)

# %%
# tensorflow import 
import tensorflow  as tf

# %%
X_train.iloc[0].shape
# Out:
# (12,)

# %%
#신경망 생성

epo = 30
model = tf.keras.Sequential([
    # tf.keras.layers.BatchNormalization(input_shape=X_train.iloc[0].shape),
    tf.keras.layers.Dense(units=256, activation='relu', input_shape=X_train.iloc[0].shape),
    tf.keras.layers.Dense(units=132, activation='relu'),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(units=1)
])

# %%
# 모형 컴파일
model.compile(loss='mean_squared_error', 
              optimizer='adam', 
              metrics=['mean_squared_error'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 256)               3328
#
#  dense_11 (Dense)            (None, 132)               33924
#
#  dense_12 (Dense)            (None, 128)               17024
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 62,597
# Trainable params: 62,597
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)

history = model.fit(X_train, y_train, 
                    epochs=100, validation_data=(X_valid, y_valid),
                    callbacks=[early_stop],batch_size=5)
history
# Out:
# Epoch 1/100
# 1350/1350 [==============================] - 8s 4ms/step - loss: 569.7732 - mean_squared_error: 569.7732 - val_loss: 193.6008 - val_mean_squared_error: 193.6008
# Epoch 2/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 152.3025 - mean_squared_error: 152.3025 - val_loss: 135.1803 - val_mean_squared_error: 135.1803
# Epoch 3/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 149.2070 - mean_squared_error: 149.2070 - val_loss: 36.5489 - val_mean_squared_error: 36.5489
# Epoch 4/100
# 1350/1350 [==============================] - 8s 6ms/step - loss: 131.4413 - mean_squared_error: 131.4413 - val_loss: 22.2778 - val_mean_squared_error: 22.2778
# Epoch 5/100
# 1350/1350 [==============================] - 6s 5ms/step - loss: 138.8795 - mean_squared_error: 138.8795 - val_loss: 32.1231 - val_mean_squared_error: 32.1231
# Epoch 6/100
# 1350/1350 [==============================] - 7s 5ms/step - loss: 126.3978 - mean_squared_error: 126.3978 - val_loss: 20.6175 - val_mean_squared_error: 20.6175
# Epoch 7/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 126.8785 - mean_squared_error: 126.8785 - val_loss: 25.4458 - val_mean_squared_error: 25.4458
# Epoch 8/100
# 1350/1350 [==============================] - 7s 5ms/step - loss: 119.3192 - mean_squared_error: 119.3192 - val_loss: 56.2464 - val_mean_squared_error: 56.2464
# Epoch 9/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 114.8980 - mean_squared_error: 114.8980 - val_loss: 40.1359 - val_mean_squared_error: 40.1359
# Epoch 10/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 115.4069 - mean_squared_error: 115.4069 - val_loss: 50.5428 - val_mean_squared_error: 50.5428
# Epoch 11/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 103.6497 - mean_squared_error: 103.6497 - val_loss: 74.7077 - val_mean_squared_error: 74.7077
# Epoch 12/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 102.8779 - mean_squared_error: 102.8779 - val_loss: 18.4176 - val_mean_squared_error: 18.4176
# Epoch 13/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 112.3309 - mean_squared_error: 112.3309 - val_loss: 46.1787 - val_mean_squared_error: 46.1787
# Epoch 14/100
# 1350/1350 [==============================] - 7s 5ms/step - loss: 103.7117 - mean_squared_error: 103.7117 - val_loss: 49.2133 - val_mean_squared_error: 49.2133
# Epoch 15/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 104.5053 - mean_squared_error: 104.5053 - val_loss: 34.0040 - val_mean_squared_error: 34.0040
# Epoch 16/100
# 1350/1350 [==============================] - 7s 5ms/step - loss: 101.3226 - mean_squared_error: 101.3226 - val_loss: 10.5491 - val_mean_squared_error: 10.5491
# Epoch 17/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 98.8974 - mean_squared_error: 98.8974 - val_loss: 19.3227 - val_mean_squared_error: 19.3227
# Epoch 18/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 99.8914 - mean_squared_error: 99.8914 - val_loss: 17.9050 - val_mean_squared_error: 17.9050
# Epoch 19/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 95.9711 - mean_squared_error: 95.9711 - val_loss: 23.3933 - val_mean_squared_error: 23.3933
# Epoch 20/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 96.3192 - mean_squared_error: 96.3192 - val_loss: 25.9736 - val_mean_squared_error: 25.9736
# Epoch 21/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 88.5001 - mean_squared_error: 88.5001 - val_loss: 16.3555 - val_mean_squared_error: 16.3555
# Epoch 22/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 87.6410 - mean_squared_error: 87.6410 - val_loss: 194.9631 - val_mean_squared_error: 194.9631
# Epoch 23/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 88.0599 - mean_squared_error: 88.0599 - val_loss: 15.6331 - val_mean_squared_error: 15.6331
# Epoch 24/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 83.4668 - mean_squared_error: 83.4668 - val_loss: 12.2087 - val_mean_squared_error: 12.2087
# Epoch 25/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 84.6604 - mean_squared_error: 84.6604 - val_loss: 8.4960 - val_mean_squared_error: 8.4960
# Epoch 26/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 87.3900 - mean_squared_error: 87.3900 - val_loss: 8.7941 - val_mean_squared_error: 8.7941
# Epoch 27/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 82.4616 - mean_squared_error: 82.4616 - val_loss: 7.6084 - val_mean_squared_error: 7.6084
# Epoch 28/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 84.1740 - mean_squared_error: 84.1740 - val_loss: 17.8735 - val_mean_squared_error: 17.8735
# Epoch 29/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 86.8743 - mean_squared_error: 86.8743 - val_loss: 7.0105 - val_mean_squared_error: 7.0105
# Epoch 30/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 83.7488 - mean_squared_error: 83.7488 - val_loss: 80.9943 - val_mean_squared_error: 80.9943
# Epoch 31/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 78.6731 - mean_squared_error: 78.6731 - val_loss: 11.8305 - val_mean_squared_error: 11.8305
# Epoch 32/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 76.7003 - mean_squared_error: 76.7003 - val_loss: 49.3320 - val_mean_squared_error: 49.3320
# Epoch 33/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 80.0882 - mean_squared_error: 80.0882 - val_loss: 14.9841 - val_mean_squared_error: 14.9841
# Epoch 34/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 81.7021 - mean_squared_error: 81.7021 - val_loss: 43.1299 - val_mean_squared_error: 43.1299
# Epoch 35/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 87.4800 - mean_squared_error: 87.4800 - val_loss: 42.9693 - val_mean_squared_error: 42.9693
# Epoch 36/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 77.6102 - mean_squared_error: 77.6102 - val_loss: 29.5760 - val_mean_squared_error: 29.5760
# Epoch 37/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 80.2529 - mean_squared_error: 80.2529 - val_loss: 36.0824 - val_mean_squared_error: 36.0824
# Epoch 38/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 75.2921 - mean_squared_error: 75.2921 - val_loss: 8.7814 - val_mean_squared_error: 8.7814
# Epoch 39/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 79.8876 - mean_squared_error: 79.8876 - val_loss: 5.2050 - val_mean_squared_error: 5.2050
# Epoch 40/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 81.8822 - mean_squared_error: 81.8822 - val_loss: 14.1648 - val_mean_squared_error: 14.1648
# Epoch 41/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 76.2656 - mean_squared_error: 76.2656 - val_loss: 6.2807 - val_mean_squared_error: 6.2807
# Epoch 42/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 80.2047 - mean_squared_error: 80.2047 - val_loss: 10.0358 - val_mean_squared_error: 10.0358
# Epoch 43/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 78.4140 - mean_squared_error: 78.4140 - val_loss: 8.2862 - val_mean_squared_error: 8.2862
# Epoch 44/100
# 1350/1350 [==============================] - 6s 5ms/step - loss: 80.3682 - mean_squared_error: 80.3682 - val_loss: 16.8940 - val_mean_squared_error: 16.8940
# Epoch 45/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 77.6243 - mean_squared_error: 77.6243 - val_loss: 4.5464 - val_mean_squared_error: 4.5464
# Epoch 46/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 73.8469 - mean_squared_error: 73.8469 - val_loss: 10.8377 - val_mean_squared_error: 10.8377
# Epoch 47/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 77.5928 - mean_squared_error: 77.5928 - val_loss: 8.5033 - val_mean_squared_error: 8.5033
# Epoch 48/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 82.4617 - mean_squared_error: 82.4617 - val_loss: 7.3043 - val_mean_squared_error: 7.3043
# Epoch 49/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 82.4175 - mean_squared_error: 82.4175 - val_loss: 58.2882 - val_mean_squared_error: 58.2882
# Epoch 50/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 78.3039 - mean_squared_error: 78.3039 - val_loss: 5.9912 - val_mean_squared_error: 5.9912
# Epoch 51/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 77.9617 - mean_squared_error: 77.9617 - val_loss: 97.8364 - val_mean_squared_error: 97.8364
# Epoch 52/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 73.8607 - mean_squared_error: 73.8607 - val_loss: 13.8069 - val_mean_squared_error: 13.8069
# Epoch 53/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 75.8458 - mean_squared_error: 75.8458 - val_loss: 8.7021 - val_mean_squared_error: 8.7021
# Epoch 54/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 76.9917 - mean_squared_error: 76.9917 - val_loss: 6.5777 - val_mean_squared_error: 6.5777
# Epoch 55/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 72.2980 - mean_squared_error: 72.2980 - val_loss: 9.4772 - val_mean_squared_error: 9.4772
# Epoch 56/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 78.7687 - mean_squared_error: 78.7687 - val_loss: 13.3704 - val_mean_squared_error: 13.3704
# Epoch 57/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 68.4528 - mean_squared_error: 68.4528 - val_loss: 8.6985 - val_mean_squared_error: 8.6985
# Epoch 58/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 74.5694 - mean_squared_error: 74.5694 - val_loss: 5.4643 - val_mean_squared_error: 5.4643
# Epoch 59/100
# 1350/1350 [==============================] - 6s 5ms/step - loss: 70.1857 - mean_squared_error: 70.1857 - val_loss: 9.0597 - val_mean_squared_error: 9.0597
# Epoch 60/100
# 1350/1350 [==============================] - 8s 6ms/step - loss: 67.5013 - mean_squared_error: 67.5013 - val_loss: 16.6421 - val_mean_squared_error: 16.6421
# Epoch 61/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 69.5018 - mean_squared_error: 69.5018 - val_loss: 6.8366 - val_mean_squared_error: 6.8366
# Epoch 62/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 72.4301 - mean_squared_error: 72.4301 - val_loss: 150.0982 - val_mean_squared_error: 150.0982
# Epoch 63/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 75.2011 - mean_squared_error: 75.2011 - val_loss: 17.9191 - val_mean_squared_error: 17.9191
# Epoch 64/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 69.5940 - mean_squared_error: 69.5940 - val_loss: 13.1835 - val_mean_squared_error: 13.1835
# Epoch 65/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 71.5050 - mean_squared_error: 71.5050 - val_loss: 23.7147 - val_mean_squared_error: 23.7147
# Epoch 66/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 68.4865 - mean_squared_error: 68.4865 - val_loss: 6.6426 - val_mean_squared_error: 6.6426
# Epoch 67/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 62.3407 - mean_squared_error: 62.3407 - val_loss: 9.2076 - val_mean_squared_error: 9.2076
# Epoch 68/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 65.6852 - mean_squared_error: 65.6852 - val_loss: 44.6241 - val_mean_squared_error: 44.6241
# Epoch 69/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 69.3787 - mean_squared_error: 69.3787 - val_loss: 9.2072 - val_mean_squared_error: 9.2072
# Epoch 70/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 73.1678 - mean_squared_error: 73.1678 - val_loss: 6.3037 - val_mean_squared_error: 6.3037
# Epoch 71/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 61.9334 - mean_squared_error: 61.9334 - val_loss: 34.5752 - val_mean_squared_error: 34.5752
# Epoch 72/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 69.0027 - mean_squared_error: 69.0027 - val_loss: 3.3844 - val_mean_squared_error: 3.3844
# Epoch 73/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 67.4220 - mean_squared_error: 67.4220 - val_loss: 23.9496 - val_mean_squared_error: 23.9496
# Epoch 74/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 68.1019 - mean_squared_error: 68.1019 - val_loss: 16.8359 - val_mean_squared_error: 16.8359
# Epoch 75/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 66.2463 - mean_squared_error: 66.2463 - val_loss: 56.3443 - val_mean_squared_error: 56.3443
# Epoch 76/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 61.6607 - mean_squared_error: 61.6607 - val_loss: 47.9108 - val_mean_squared_error: 47.9108
# Epoch 77/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 72.4493 - mean_squared_error: 72.4493 - val_loss: 37.1913 - val_mean_squared_error: 37.1913
# Epoch 78/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 69.7208 - mean_squared_error: 69.7208 - val_loss: 7.7503 - val_mean_squared_error: 7.7503
# Epoch 79/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 68.2995 - mean_squared_error: 68.2995 - val_loss: 24.5035 - val_mean_squared_error: 24.5035
# Epoch 80/100
# 1350/1350 [==============================] - 6s 5ms/step - loss: 66.8378 - mean_squared_error: 66.8378 - val_loss: 13.5525 - val_mean_squared_error: 13.5525
# Epoch 81/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 68.4070 - mean_squared_error: 68.4070 - val_loss: 34.0910 - val_mean_squared_error: 34.0910
# Epoch 82/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 67.3352 - mean_squared_error: 67.3352 - val_loss: 4.3617 - val_mean_squared_error: 4.3617
# Epoch 83/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 71.7503 - mean_squared_error: 71.7503 - val_loss: 3.2041 - val_mean_squared_error: 3.2041
# Epoch 84/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 65.4060 - mean_squared_error: 65.4060 - val_loss: 31.7722 - val_mean_squared_error: 31.7722
# Epoch 85/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 70.7438 - mean_squared_error: 70.7438 - val_loss: 6.1090 - val_mean_squared_error: 6.1090
# Epoch 86/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 63.5529 - mean_squared_error: 63.5529 - val_loss: 6.5181 - val_mean_squared_error: 6.5181
# Epoch 87/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 64.1016 - mean_squared_error: 64.1016 - val_loss: 4.7872 - val_mean_squared_error: 4.7872
# Epoch 88/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 64.9105 - mean_squared_error: 64.9105 - val_loss: 24.1153 - val_mean_squared_error: 24.1153
# Epoch 89/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 65.6114 - mean_squared_error: 65.6114 - val_loss: 4.0650 - val_mean_squared_error: 4.0650
# Epoch 90/100
# 1350/1350 [==============================] - 5s 4ms/step - loss: 63.1258 - mean_squared_error: 63.1258 - val_loss: 9.4316 - val_mean_squared_error: 9.4316
# Epoch 91/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 69.1581 - mean_squared_error: 69.1581 - val_loss: 28.1287 - val_mean_squared_error: 28.1287
# Epoch 92/100
# 1350/1350 [==============================] - 5s 3ms/step - loss: 64.2926 - mean_squared_error: 64.2926 - val_loss: 7.9114 - val_mean_squared_error: 7.9114
# Epoch 93/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 69.8553 - mean_squared_error: 69.8553 - val_loss: 5.8956 - val_mean_squared_error: 5.8956
# Epoch 94/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 61.3314 - mean_squared_error: 61.3314 - val_loss: 5.6646 - val_mean_squared_error: 5.6646
# Epoch 95/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 65.0327 - mean_squared_error: 65.0327 - val_loss: 8.7483 - val_mean_squared_error: 8.7483
# Epoch 96/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 63.8581 - mean_squared_error: 63.8581 - val_loss: 48.0140 - val_mean_squared_error: 48.0140
# Epoch 97/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 62.1805 - mean_squared_error: 62.1805 - val_loss: 22.6393 - val_mean_squared_error: 22.6393
# Epoch 98/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 64.5082 - mean_squared_error: 64.5082 - val_loss: 9.5267 - val_mean_squared_error: 9.5267
# Epoch 99/100
# 1350/1350 [==============================] - 4s 3ms/step - loss: 61.7922 - mean_squared_error: 61.7922 - val_loss: 21.4513 - val_mean_squared_error: 21.4513
# Epoch 100/100
# 1350/1350 [==============================] - 6s 4ms/step - loss: 66.1362 - mean_squared_error: 66.1362 - val_loss: 43.3929 - val_mean_squared_error: 43.3929

# %%
# 트레이닝 데이터 평가
print(model.evaluate(X_valid, y_valid)[1])
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2831 - mean_squared_error: 6.2831
# 6.283114433288574

# %%
mse = history.history['mean_squared_error'] 
print(mse)
# Out:
# [596.2760620117188, 154.0333709716797, 142.40838623046875, 141.05784606933594, 135.56591796875, 119.86624908447266, 131.9001007080078, 116.12102508544922, 118.18297576904297, 111.38224029541016, 110.67039489746094, 110.61607360839844, 106.80516052246094, 107.5972671508789, 103.70979309082031, 108.83108520507812, 110.9529037475586, 106.77031707763672, 107.50328826904297, 100.19044494628906, 105.22174072265625, 95.2842025756836, 97.7431411743164, 94.16226959228516, 90.3538818359375, 94.92071533203125, 91.6607894897461, 94.68253326416016, 92.04187774658203, 88.06727600097656, 91.1314926147461, 82.11420440673828, 87.30779266357422, 85.32319641113281, 88.00797271728516, 85.29624938964844, 78.88319396972656, 79.36746215820312, 81.27953338623047, 83.17426300048828, 79.62261962890625, 75.70852661132812, 79.80171966552734, 84.19940185546875, 79.30046081542969, 80.28185272216797, 82.27542877197266, 79.50452423095703, 76.13279724121094, 77.09146881103516, 72.95042419433594, 79.65796661376953, 75.57171630859375, 74.1568603515625, 73.76545715332031, 73.60240173339844, 74.30030059814453, 70.8465805053711, 72.68692016601562, 72.11644744873047, 73.02747344970703, 71.26386260986328, 71.78324890136719, 68.26351165771484, 73.83797454833984, 70.83827209472656, 71.40017700195312, 70.78640747070312, 70.29609680175781, 67.4241943359375, 73.39517211914062, 73.99850463867188, 68.9305191040039, 70.0518569946289, 69.91448974609375, 67.25940704345703, 68.80621337890625, 71.36207580566406, 68.00720977783203, 65.44070434570312, 66.80436706542969, 63.41250991821289, 64.49259948730469, 66.3100814819336, 63.285430908203125, 61.12385559082031, 62.24501037597656, 65.40281677246094, 60.29035186767578, 66.6317138671875, 62.7657470703125, 60.1256217956543, 62.16909408569336, 62.02655029296875, 61.78293991088867, 58.84397506713867, 60.38921356201172, 60.207496643066406, 63.93647766113281, 55.97380065917969]

# %%
loss = history.history['loss'] 
print(loss)
# Out:
# [596.2760620117188, 154.0333709716797, 142.40838623046875, 141.05784606933594, 135.56591796875, 119.86624908447266, 131.9001007080078, 116.12102508544922, 118.1829605102539, 111.38224029541016, 110.67039489746094, 110.61607360839844, 106.80516052246094, 107.59725952148438, 103.70979309082031, 108.83108520507812, 110.9529037475586, 106.77031707763672, 107.50328826904297, 100.19044494628906, 105.22174835205078, 95.2842025756836, 97.7431411743164, 94.16226959228516, 90.3538818359375, 94.92071533203125, 91.6607894897461, 94.68253326416016, 92.04187774658203, 88.06727600097656, 91.1314926147461, 82.11420440673828, 87.30779266357422, 85.32319641113281, 88.00797271728516, 85.29624938964844, 78.88319396972656, 79.36746215820312, 81.27953338623047, 83.17426300048828, 79.62261962890625, 75.70852661132812, 79.8017349243164, 84.19940185546875, 79.30046081542969, 80.28185272216797, 82.27542877197266, 79.50452423095703, 76.13279724121094, 77.09146881103516, 72.95042419433594, 79.65796661376953, 75.57172393798828, 74.1568603515625, 73.76545715332031, 73.60240173339844, 74.30030059814453, 70.8465805053711, 72.68692016601562, 72.11644744873047, 73.02747344970703, 71.26386260986328, 71.78324890136719, 68.26351165771484, 73.83797454833984, 70.83827209472656, 71.40017700195312, 70.78640747070312, 70.29609680175781, 67.4241943359375, 73.39517211914062, 73.99850463867188, 68.9305191040039, 70.0518569946289, 69.91448974609375, 67.25940704345703, 68.80621337890625, 71.36207580566406, 68.00720977783203, 65.44070434570312, 66.80436706542969, 63.41250991821289, 64.49259948730469, 66.3100814819336, 63.285430908203125, 61.12385559082031, 62.24501037597656, 65.40281677246094, 60.29035186767578, 66.6317138671875, 62.7657470703125, 60.1256217956543, 62.16909408569336, 62.02655029296875, 61.78293991088867, 58.84397506713867, 60.38921356201172, 60.207496643066406, 63.93647766113281, 55.97380065917969]

# %%
# 손실 학습 그래프
import matplotlib.pyplot as plt
plt.plot(epochs, loss, 'r', label='loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-1f5ea26efb37> in <cell line: 3>()
#       1 # 손실 학습 그래프
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.plot(epochs, loss, 'r', label='loss')
#       4 plt.xlabel('epoch')
#       5 plt.ylabel('loss')
#
# NameError: name 'epochs' is not defined

# %%
# MSE 학습 그래프
import matplotlib.pyplot as plt
plt.plot(epochs, mse, label='mse')
plt.xlabel('epochs')
plt.ylabel('mean_squred_error')
plt.legend()
plt.show()

# %%
loss = history.history['loss'] 
print(loss)

# %%
# 실제값, 예측값 데이터 프레임 생성
pred_y = model.predict(X_test).flatten() 
print(pred_y)

# %%
import pandas as pd
res_df = pd.DataFrame(pred_y, columns=['predict_val'])
res_df['real_val'] = y_te

# %%
# df_hist
df_hist = pd.DataFrame(history.history)
df_hist.tail()
# Out:
#            loss         mse        mae   val_loss    val_mse   val_mae
# 102  258.762878  258.762878  11.733859  12.899782  12.899782  2.504675
# 103  219.906006  219.906006  10.983678  98.471199  98.471199  7.960688
# 104  235.977921  235.977921  11.155920  41.703381  41.703381  5.114644
# 105  206.948273  206.948273  10.472921  37.379745  37.379745  4.771301
# 106  201.572540  201.572540  10.372279  55.492741  55.492741  5.322543

# %%
# mse plot
df_hist[['mse','val_mse']].plot()
# Out:
# <Axes: >

# %%
# loss, mae, mse = model.evaluate
model.evaluate(X_valid, y_valid)
# Out:
# 24/24 [==============================] - 0s 3ms/step - loss: 55.4927 - mse: 55.4927 - mae: 5.3225
# [55.492740631103516, 55.492740631103516, 5.322542667388916]

# %%
# predict
y_valid_pred = model.predict(X_valid).flatten()
y_valid_pred[:5]
# Out:
# 24/24 [==============================] - 0s 2ms/step
# array([ 17.348875, 126.46677 , 114.67315 ,  16.398977,  21.568396],
#       dtype=float32)

# %%
# predict
y_predict = model.predict(X_test).flatten()
y_predict[:5]
# Out:
# 235/235 [==============================] - 0s 2ms/step
# array([165.2305  , 175.45537 ,  52.128338, 154.35608 , 204.77536 ],
#       dtype=float32)

# %%
# jointplot
sns.jointplot(x=y_valid, y=y_valid_pred, kind="reg", color='green')

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_valid, y_valid_pred)
r2
# Out:
# 0.9860890522099051

# %%
sample_submission["Calories_Burned"] = y_predict 
sample_submission
# Out:
#            Calories_Burned
# ID
# TEST_0000       165.230499
# TEST_0001       175.455368
# TEST_0002        52.128338
# TEST_0003       154.356079
# TEST_0004       204.775360
# ...                    ...
# TEST_7495       181.736267
# TEST_7496        10.845786
# TEST_7497       125.655891
# TEST_7498        29.739300
# TEST_7499       173.160889
#
# [7500 rows x 1 columns]

# %%
file_name = f"submit_tf_{r2:.5f}.csv"
file_name
# Out:
# 'submit_tf_0.98609.csv'

# %%
sample_submission.to_csv(file_name)
pd.read_csv(file_name).head()
# Out:
#           ID  Calories_Burned
# 0  TEST_0000       165.230500
# 1  TEST_0001       175.455370
# 2  TEST_0002        52.128338
# 3  TEST_0003       154.356080
# 4  TEST_0004       204.775360
