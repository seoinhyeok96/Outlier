# %% [markdown]
# # 칼로리 Dacon

# %%
import pandas as pd 
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # 데이터 로드

# %%
train = pd.read_csv('data/칼로리/train.csv')
test = pd.read_csv('data/칼로리/test.csv')

train.head(2)
# Out:
#            ID  Exercise_Duration  Body_Temperature(F)    BPM  Height(Feet)  \
# 0  TRAIN_0000               26.0                105.6  107.0           5.0
# 1  TRAIN_0001                7.0                103.3   88.0           6.0
#
#    Height(Remainder_Inches)  Weight(lb)  Weight_Status Gender  Age  \
# 0                       9.0       154.3  Normal Weight      F   45
# 1                       6.0       224.9     Overweight      M   50
#
#    Calories_Burned
# 0            166.0
# 1             33.0

# %%
train.isnull().sum()
# Out:
# ID                          0
# Exercise_Duration           0
# Body_Temperature(F)         0
# BPM                         0
# Height(Feet)                0
# Height(Remainder_Inches)    0
# Weight(lb)                  0
# Weight_Status               0
# Gender                      0
# Age                         0
# Calories_Burned             0
# dtype: int64

# %%
train.columns
# Out:
# Index(['ID', 'Exercise_Duration', 'Body_Temperature(F)', 'BPM', 'Height(Feet)',
#        'Height(Remainder_Inches)', 'Weight(lb)', 'Weight_Status', 'Gender',
#        'Age', 'Calories_Burned'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        7500 non-null   object
#  1   Exercise_Duration         7500 non-null   float64
#  2   Body_Temperature(F)       7500 non-null   float64
#  3   BPM                       7500 non-null   float64
#  4   Height(Feet)              7500 non-null   float64
#  5   Height(Remainder_Inches)  7500 non-null   float64
#  6   Weight(lb)                7500 non-null   float64
#  7   Weight_Status             7500 non-null   object
#  8   Gender                    7500 non-null   object
#  9   Age                       7500 non-null   int64
#  10  Calories_Burned           7500 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 644.7+ KB

# %%
train.describe()
# Out:
#        Exercise_Duration  Body_Temperature(F)          BPM  Height(Feet)  \
# count          7500.0000          7500.000000  7500.000000   7500.000000
# mean             15.5012           104.033573    95.498133      5.248800
# std               8.3553             1.412845     9.587331      0.556663
# min               1.0000            98.800000    69.000000      4.000000
# 25%               8.0000           103.300000    88.000000      5.000000
# 50%              15.0000           104.400000    95.000000      5.000000
# 75%              23.0000           105.100000   103.000000      6.000000
# max              30.0000           106.700000   128.000000      7.000000
#
#        Height(Remainder_Inches)   Weight(lb)          Age  Calories_Burned
# count               7500.000000  7500.000000  7500.000000      7500.000000
# mean                   5.717600   165.361187    42.636000        89.373467
# std                    3.497315    33.308136    16.883188        62.817086
# min                    0.000000    79.400000    20.000000         1.000000
# 25%                    3.000000   138.900000    28.000000        35.000000
# 50%                    6.000000   163.100000    39.000000        77.000000
# 75%                    9.000000   191.800000    56.000000       138.000000
# max                   12.000000   291.000000    79.000000       300.000000

# %%
train.head(2)
# Out:
#            ID  Exercise_Duration  Body_Temperature(F)    BPM  Height(Feet)  \
# 0  TRAIN_0000               26.0                105.6  107.0           5.0
# 1  TRAIN_0001                7.0                103.3   88.0           6.0
#
#    Height(Remainder_Inches)  Weight(lb)  Weight_Status Gender  Age  \
# 0                       9.0       154.3  Normal Weight      F   45
# 1                       6.0       224.9     Overweight      M   50
#
#    Calories_Burned
# 0            166.0
# 1             33.0

# %%
test.head(2)
# Out:
#           ID  Exercise_Duration  Body_Temperature(F)    BPM  Height(Feet)  \
# 0  TEST_0000               26.0                105.1  107.0           5.0
# 1  TEST_0001               29.0                104.9  111.0           6.0
#
#    Height(Remainder_Inches)  Weight(lb)  Weight_Status Gender  Age
# 0                       1.0       114.6  Normal Weight      F   45
# 1                       2.0       198.4     Overweight      M   21

# %% [markdown]
# # 컬럼 수치단위변환

# %% [markdown]
# 키, 몸무게. 신체온도를 각각 cm, kg, c 단위로 변환해줌

# %% [markdown]
# d (cm) = d (피트) × 30.48 + d (인치) × 2.54

# %%
train['Height'] = train['Height(Feet)']*30.48 + train['Height(Remainder_Inches)']*2.54

# %%
train.drop(['Height(Feet)', 'Height(Remainder_Inches)'], axis=1)
# Out:
#               ID  Exercise_Duration  Body_Temperature(F)    BPM  Weight(lb)  \
# 0     TRAIN_0000               26.0                105.6  107.0       154.3
# 1     TRAIN_0001                7.0                103.3   88.0       224.9
# 2     TRAIN_0002                7.0                103.3   86.0       218.3
# 3     TRAIN_0003               17.0                104.0   99.0       147.7
# 4     TRAIN_0004                9.0                102.7   88.0       169.8
# ...          ...                ...                  ...    ...         ...
# 7495  TRAIN_7495               22.0                105.1  104.0       112.4
# 7496  TRAIN_7496               20.0                105.3  104.0       147.7
# 7497  TRAIN_7497                8.0                103.1   90.0       202.8
# 7498  TRAIN_7498               12.0                104.4   97.0       167.6
# 7499  TRAIN_7499               16.0                104.9   91.0       189.6
#
#       Weight_Status Gender  Age  Calories_Burned  Height
# 0     Normal Weight      F   45            166.0  175.26
# 1        Overweight      M   50             33.0  198.12
# 2        Overweight      M   29             23.0  190.50
# 3     Normal Weight      F   33             91.0  167.64
# 4     Normal Weight      M   38             32.0  177.80
# ...             ...    ...  ...              ...     ...
# 7495  Normal Weight      F   75            151.0  147.32
# 7496  Normal Weight      F   21            114.0  172.72
# 7497     Overweight      M   57             41.0  187.96
# 7498     Overweight      M   35             57.0  175.26
# 7499     Overweight      M   26             59.0  182.88
#
# [7500 rows x 10 columns]

# %%
train = train.copy()
train['Body_Temperature'] = (train['Body_Temperature(F)'] - 32) / 1.8

# %%
# Weight in kg = Weight in lb * 0.45359237

train['Weight']= train['Weight(lb)']* 0.45359237
train
# Out:
#               ID  Exercise_Duration  Body_Temperature(F)    BPM  Height(Feet)  \
# 0     TRAIN_0000               26.0                105.6  107.0           5.0
# 1     TRAIN_0001                7.0                103.3   88.0           6.0
# 2     TRAIN_0002                7.0                103.3   86.0           6.0
# 3     TRAIN_0003               17.0                104.0   99.0           5.0
# 4     TRAIN_0004                9.0                102.7   88.0           5.0
# ...          ...                ...                  ...    ...           ...
# 7495  TRAIN_7495               22.0                105.1  104.0           4.0
# 7496  TRAIN_7496               20.0                105.3  104.0           5.0
# 7497  TRAIN_7497                8.0                103.1   90.0           6.0
# 7498  TRAIN_7498               12.0                104.4   97.0           5.0
# 7499  TRAIN_7499               16.0                104.9   91.0           5.0
#
#       Height(Remainder_Inches)  Weight(lb)  Weight_Status Gender  Age  \
# 0                          9.0       154.3  Normal Weight      F   45
# 1                          6.0       224.9     Overweight      M   50
# 2                          3.0       218.3     Overweight      M   29
# 3                          6.0       147.7  Normal Weight      F   33
# 4                         10.0       169.8  Normal Weight      M   38
# ...                        ...         ...            ...    ...  ...
# 7495                      10.0       112.4  Normal Weight      F   75
# 7496                       8.0       147.7  Normal Weight      F   21
# 7497                       2.0       202.8     Overweight      M   57
# 7498                       9.0       167.6     Overweight      M   35
# 7499                      12.0       189.6     Overweight      M   26
#
#       Calories_Burned  Height  Body_Temperature      Weight
# 0               166.0  175.26         40.888889   69.989303
# 1                33.0  198.12         39.611111  102.012924
# 2                23.0  190.50         39.611111   99.019214
# 3                91.0  167.64         40.000000   66.995593
# 4                32.0  177.80         39.277778   77.019984
# ...               ...     ...               ...         ...
# 7495            151.0  147.32         40.611111   50.983782
# 7496            114.0  172.72         40.722222   66.995593
# 7497             41.0  187.96         39.500000   91.988533
# 7498             57.0  175.26         40.222222   76.022081
# 7499             59.0  182.88         40.500000   86.001113
#
# [7500 rows x 14 columns]

# %%
train.drop(['Body_Temperature(F)', 'Weight(lb)'], axis=1)
# Out:
#               ID  Exercise_Duration    BPM  Height(Feet)  \
# 0     TRAIN_0000               26.0  107.0           5.0
# 1     TRAIN_0001                7.0   88.0           6.0
# 2     TRAIN_0002                7.0   86.0           6.0
# 3     TRAIN_0003               17.0   99.0           5.0
# 4     TRAIN_0004                9.0   88.0           5.0
# ...          ...                ...    ...           ...
# 7495  TRAIN_7495               22.0  104.0           4.0
# 7496  TRAIN_7496               20.0  104.0           5.0
# 7497  TRAIN_7497                8.0   90.0           6.0
# 7498  TRAIN_7498               12.0   97.0           5.0
# 7499  TRAIN_7499               16.0   91.0           5.0
#
#       Height(Remainder_Inches)  Weight_Status Gender  Age  Calories_Burned  \
# 0                          9.0  Normal Weight      F   45            166.0
# 1                          6.0     Overweight      M   50             33.0
# 2                          3.0     Overweight      M   29             23.0
# 3                          6.0  Normal Weight      F   33             91.0
# 4                         10.0  Normal Weight      M   38             32.0
# ...                        ...            ...    ...  ...              ...
# 7495                      10.0  Normal Weight      F   75            151.0
# 7496                       8.0  Normal Weight      F   21            114.0
# 7497                       2.0     Overweight      M   57             41.0
# 7498                       9.0     Overweight      M   35             57.0
# 7499                      12.0     Overweight      M   26             59.0
#
#       Height  Body_Temperature      Weight
# 0     175.26         40.888889   69.989303
# 1     198.12         39.611111  102.012924
# 2     190.50         39.611111   99.019214
# 3     167.64         40.000000   66.995593
# 4     177.80         39.277778   77.019984
# ...      ...               ...         ...
# 7495  147.32         40.611111   50.983782
# 7496  172.72         40.722222   66.995593
# 7497  187.96         39.500000   91.988533
# 7498  175.26         40.222222   76.022081
# 7499  182.88         40.500000   86.001113
#
# [7500 rows x 12 columns]

# %%
train = train[['ID', 'Exercise_Duration', 'Body_Temperature', 'BPM',
       'Height', 'Weight', 'Weight_Status', 'Gender',
       'Age', 'Calories_Burned']]

# %%
train
# Out:
#               ID  Exercise_Duration  Body_Temperature    BPM  Height  \
# 0     TRAIN_0000               26.0         40.888889  107.0  175.26
# 1     TRAIN_0001                7.0         39.611111   88.0  198.12
# 2     TRAIN_0002                7.0         39.611111   86.0  190.50
# 3     TRAIN_0003               17.0         40.000000   99.0  167.64
# 4     TRAIN_0004                9.0         39.277778   88.0  177.80
# ...          ...                ...               ...    ...     ...
# 7495  TRAIN_7495               22.0         40.611111  104.0  147.32
# 7496  TRAIN_7496               20.0         40.722222  104.0  172.72
# 7497  TRAIN_7497                8.0         39.500000   90.0  187.96
# 7498  TRAIN_7498               12.0         40.222222   97.0  175.26
# 7499  TRAIN_7499               16.0         40.500000   91.0  182.88
#
#           Weight  Weight_Status Gender  Age  Calories_Burned
# 0      69.989303  Normal Weight      F   45            166.0
# 1     102.012924     Overweight      M   50             33.0
# 2      99.019214     Overweight      M   29             23.0
# 3      66.995593  Normal Weight      F   33             91.0
# 4      77.019984  Normal Weight      M   38             32.0
# ...          ...            ...    ...  ...              ...
# 7495   50.983782  Normal Weight      F   75            151.0
# 7496   66.995593  Normal Weight      F   21            114.0
# 7497   91.988533     Overweight      M   57             41.0
# 7498   76.022081     Overweight      M   35             57.0
# 7499   86.001113     Overweight      M   26             59.0
#
# [7500 rows x 10 columns]

# %%
test['Body_Temperature'] = (test['Body_Temperature(F)'] - 32) / 1.8
test['Height'] = test['Height(Feet)']*30.48 + test['Height(Remainder_Inches)']*2.54
test['Weight']= test['Weight(lb)']* 0.45359237

# %%
test.drop(['Body_Temperature(F)','Height(Feet)', 'Height(Remainder_Inches)', 'Weight(lb)'], axis=1)
# Out:
#              ID  Exercise_Duration    BPM  Weight_Status Gender  Age  \
# 0     TEST_0000               26.0  107.0  Normal Weight      F   45
# 1     TEST_0001               29.0  111.0     Overweight      M   21
# 2     TEST_0002               11.0   90.0  Normal Weight      M   58
# 3     TEST_0003               24.0  108.0     Overweight      M   35
# 4     TEST_0004               29.0  116.0  Normal Weight      F   67
# ...         ...                ...    ...            ...    ...  ...
# 7495  TEST_7495               28.0  106.0  Normal Weight      M   51
# 7496  TEST_7496                4.0   84.0     Overweight      M   25
# 7497  TEST_7497               24.0   97.0  Normal Weight      F   42
# 7498  TEST_7498                8.0   83.0  Normal Weight      F   48
# 7499  TEST_7499               29.0  107.0  Normal Weight      F   44
#
#       Body_Temperature  Height     Weight
# 0            40.611111  154.94  51.981686
# 1            40.500000  187.96  89.992726
# 2            40.000000  175.26  77.019984
# 3            40.777778  182.88  88.994823
# 4            41.111111  170.18  66.995593
# ...                ...     ...        ...
# 7495         40.888889  182.88  81.011597
# 7496         38.888889  177.80  83.007404
# 7497         40.611111  157.48  59.012367
# 7498         39.500000  165.10  61.008174
# 7499         40.888889  154.94  55.020754
#
# [7500 rows x 9 columns]

# %%
test = test[['ID', 'Exercise_Duration', 'Body_Temperature', 'BPM',
       'Height', 'Weight', 'Weight_Status', 'Gender',
       'Age']]

# %%
plt.figure(figsize=(12,12))
sns.heatmap(train.corr(), annot=True, cmap="Blues")
plt.show()

# %%
train.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_d2efe_row0_col0, #T_d2efe_row1_col1, #T_d2efe_row2_col2, #T_d2efe_row3_col3, #T_d2efe_row4_col4, #T_d2efe_row5_col5, #T_d2efe_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d2efe_row0_col1, #T_d2efe_row1_col0 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_d2efe_row0_col2, #T_d2efe_row2_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_d2efe_row0_col3, #T_d2efe_row0_col4, #T_d2efe_row2_col5, #T_d2efe_row3_col0, #T_d2efe_row3_col1, #T_d2efe_row3_col2, #T_d2efe_row3_col5, #T_d2efe_row3_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d2efe_row0_col5, #T_d2efe_row1_col3, #T_d2efe_row1_col4, #T_d2efe_row1_col5, #T_d2efe_row4_col0, #T_d2efe_row4_col1, #T_d2efe_row4_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d2efe_row0_col6, #T_d2efe_row6_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_d2efe_row1_col2 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_d2efe_row1_col6, #T_d2efe_row6_col1 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_d2efe_row2_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_d2efe_row2_col3, #T_d2efe_row2_col4, #T_d2efe_row5_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d2efe_row2_col6 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_d2efe_row3_col4, #T_d2efe_row4_col3 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_d2efe_row4_col5 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_d2efe_row4_col6, #T_d2efe_row5_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d2efe_row5_col1, #T_d2efe_row5_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d2efe_row5_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_d2efe_row5_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_d2efe_row6_col2 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_d2efe_row6_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_d2efe_row6_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_d2efe_row6_col5 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# </style>
# <table id="T_d2efe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2efe_level0_col0" class="col_heading level0 col0" >Exercise_Duration</th>
#       <th id="T_d2efe_level0_col1" class="col_heading level0 col1" >Body_Temperature</th>
#       <th id="T_d2efe_level0_col2" class="col_heading level0 col2" >BPM</th>
#       <th id="T_d2efe_level0_col3" class="col_heading level0 col3" >Height</th>
#       <th id="T_d2efe_level0_col4" class="col_heading level0 col4" >Weight</th>
#       <th id="T_d2efe_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_d2efe_level0_col6" class="col_heading level0 col6" >Calories_Burned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2efe_level0_row0" class="row_heading level0 row0" >Exercise_Duration</th>
#       <td id="T_d2efe_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d2efe_row0_col1" class="data row0 col1" >0.904314</td>
#       <td id="T_d2efe_row0_col2" class="data row0 col2" >0.853489</td>
#       <td id="T_d2efe_row0_col3" class="data row0 col3" >-0.003146</td>
#       <td id="T_d2efe_row0_col4" class="data row0 col4" >0.002236</td>
#       <td id="T_d2efe_row0_col5" class="data row0 col5" >0.017734</td>
#       <td id="T_d2efe_row0_col6" class="data row0 col6" >0.954783</td>
#     </tr>
#     <tr>
#       <th id="T_d2efe_level0_row1" class="row_heading level0 row1" >Body_Temperature</th>
#       <td id="T_d2efe_row1_col0" class="data row1 col0" >0.904314</td>
#       <td id="T_d2efe_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d2efe_row1_col2" class="data row1 col2" >0.770707</td>
#       <td id="T_d2efe_row1_col3" class="data row1 col3" >0.002979</td>
#       <td id="T_d2efe_row1_col4" class="data row1 col4" >0.007554</td>
#       <td id="T_d2efe_row1_col5" class="data row1 col5" >0.016474</td>
#       <td id="T_d2efe_row1_col6" class="data row1 col6" >0.824379</td>
#     </tr>
#     <tr>
#       <th id="T_d2efe_level0_row2" class="row_heading level0 row2" >BPM</th>
#       <td id="T_d2efe_row2_col0" class="data row2 col0" >0.853489</td>
#       <td id="T_d2efe_row2_col1" class="data row2 col1" >0.770707</td>
#       <td id="T_d2efe_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d2efe_row2_col3" class="data row2 col3" >0.006319</td>
#       <td id="T_d2efe_row2_col4" class="data row2 col4" >0.012562</td>
#       <td id="T_d2efe_row2_col5" class="data row2 col5" >0.014702</td>
#       <td id="T_d2efe_row2_col6" class="data row2 col6" >0.899900</td>
#     </tr>
#     <tr>
#       <th id="T_d2efe_level0_row3" class="row_heading level0 row3" >Height</th>
#       <td id="T_d2efe_row3_col0" class="data row3 col0" >-0.003146</td>
#       <td id="T_d2efe_row3_col1" class="data row3 col1" >0.002979</td>
#       <td id="T_d2efe_row3_col2" class="data row3 col2" >0.006319</td>
#       <td id="T_d2efe_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d2efe_row3_col4" class="data row3 col4" >0.957816</td>
#       <td id="T_d2efe_row3_col5" class="data row3 col5" >0.011184</td>
#       <td id="T_d2efe_row3_col6" class="data row3 col6" >0.021906</td>
#     </tr>
#     <tr>
#       <th id="T_d2efe_level0_row4" class="row_heading level0 row4" >Weight</th>
#       <td id="T_d2efe_row4_col0" class="data row4 col0" >0.002236</td>
#       <td id="T_d2efe_row4_col1" class="data row4 col1" >0.007554</td>
#       <td id="T_d2efe_row4_col2" class="data row4 col2" >0.012562</td>
#       <td id="T_d2efe_row4_col3" class="data row4 col3" >0.957816</td>
#       <td id="T_d2efe_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_d2efe_row4_col5" class="data row4 col5" >0.090536</td>
#       <td id="T_d2efe_row4_col6" class="data row4 col6" >0.042568</td>
#     </tr>
#     <tr>
#       <th id="T_d2efe_level0_row5" class="row_heading level0 row5" >Age</th>
#       <td id="T_d2efe_row5_col0" class="data row5 col0" >0.017734</td>
#       <td id="T_d2efe_row5_col1" class="data row5 col1" >0.016474</td>
#       <td id="T_d2efe_row5_col2" class="data row5 col2" >0.014702</td>
#       <td id="T_d2efe_row5_col3" class="data row5 col3" >0.011184</td>
#       <td id="T_d2efe_row5_col4" class="data row5 col4" >0.090536</td>
#       <td id="T_d2efe_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_d2efe_row5_col6" class="data row5 col6" >0.159624</td>
#     </tr>
#     <tr>
#       <th id="T_d2efe_level0_row6" class="row_heading level0 row6" >Calories_Burned</th>
#       <td id="T_d2efe_row6_col0" class="data row6 col0" >0.954783</td>
#       <td id="T_d2efe_row6_col1" class="data row6 col1" >0.824379</td>
#       <td id="T_d2efe_row6_col2" class="data row6 col2" >0.899900</td>
#       <td id="T_d2efe_row6_col3" class="data row6 col3" >0.021906</td>
#       <td id="T_d2efe_row6_col4" class="data row6 col4" >0.042568</td>
#       <td id="T_d2efe_row6_col5" class="data row6 col5" >0.159624</td>
#       <td id="T_d2efe_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.displot(train['Calories_Burned'])
plt.show()
#칼로리 버닝은 뒤로 갈수록 그 횟수가 줄어든다.?

# %%
sns.barplot(x = train['Weight_Status'], y=train['Calories_Burned'])
plt.show()
# 체중의상태: 데이터셋에서 무거운사람의 분포가 더 많다.

# %% [markdown]
# # ML

# %% [markdown]
# ## DecisionTreeRegressor

# %% [markdown]
# Decision tree 모델은 다음과 같은 경우에 사용할 수 있습니다:
#
# 분류(Classification): Decision tree 모델은 범주형(target variable이 discrete한 값) 데이터에 대한 분류(Classification)에 사용될 수 있습니다. 예를 들어, 스팸 메일 필터링, 고객 신용 평가, 질병 진단 등과 같은 문제에서 사용할 수 있습니다.
#
# 회귀(Regression): Decision tree 모델은 연속형(target variable이 연속적인 값) 데이터에 대한 회귀(Regression)에도 사용될 수 있습니다. 예를 들어, 주택 가격 예측, 판매량 예측, 주식 가격 예측 등과 같은 문제에서 사용할 수 있습니다.
#
# 해석 가능성 필요한 경우: Decision tree 모델은 분류나 회귀 결과를 해석하기 쉽게 나타내기 때문에, 모델의 결과를 이해하고 해석해야 하는 경우에 유용합니다. 모델의 분기점(split point)들과 결정 규칙(decision rules)을 시각적으로 확인할 수 있어, 모델의 예측을 해석하고 설명하기 쉽습니다.
#
# 비선형 관계를 가진 데이터: Decision tree 모델은 비선형(non-linear) 관계를 가진 데이터를 다룰 수 있습니다. 데이터가 복잡한 비선형 패턴을 가지고 있을 때, Decision tree 모델은 선형 모델보다 더 좋은 성능을 발휘할 수 있습니다.
#
# Feature의 중요도 파악이 필요한 경우: Decision tree 모델은 Feature(입력 변수)들의 중요도를 평가할 수 있습니다. 트리 모델에서 Feature가 선택되는 순서를 통해 각 Feature의 중요도를 파악할 수 있습니다. 이를 통해 Feature의 영향력을 평가하고, Feature 선택이나 Feature 엔지니어링에 도움을 줄 수 있습니다.
#
# 작은 규모의 데이터셋: Decision tree 모델은 작은 규모의 데이터셋에도 적용하기 좋습니다. 데이터의 크기가 작은 경우에도 Decision tree 모델은 높은 정확도를 갖고, 빠르게 학습하고 예측할 수 있습니다.

# %%
X_train = train.drop(['ID', 'Calories_Burned'], axis = 1)
y_train = train['Calories_Burned']

X_test = test.drop('ID', axis =1)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor

# Define the ordinal features that need to be encoded
ordinal_features = ['Weight_Status', 'Gender']

# Loop through the ordinal features and perform label encoding
for feature in ordinal_features:
    le = LabelEncoder()
    le.fit(train[feature])
    train.loc[:, feature] = le.transform(train[feature].copy())
    test.loc[:, feature] = le.transform(test[feature].copy())

# Split the data into X_train, y_train, X_test, and perform model fitting
X_train = train.drop(['ID', 'Calories_Burned'], axis=1)
y_train = train['Calories_Burned']
X_test = test.drop('ID', axis=1)
# Out:
# C:\Users\dk749\AppData\Local\Temp\ipykernel_10088\210373632.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[:, feature] = le.transform(train[feature].copy())

# %%
X_train.shape ,X_test.shape, y_train.shape
# Out:
# ((7500, 8), (7500, 8), (7500,))

# %%
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
preds = model.predict(X_test)

# %%
submit= pd.read_csv('data/칼로리/sample_submission.csv')

# %%
submit.head()
# Out:
#           ID  Calories_Burned
# 0  TEST_0000                0
# 1  TEST_0001                0
# 2  TEST_0002                0
# 3  TEST_0003                0
# 4  TEST_0004                0

# %%
submit['Calories_Burned'] = preds

# %%
submit.head(2)
# Out:
#           ID  Calories_Burned
# 0  TEST_0000            174.0
# 1  TEST_0001            178.0

# %%
#submit.to_csv('./Calories.DTR.csv', index = False)

# %% [markdown]
# ## Catboost

# %%
train = train.set_index(['ID'])
test = test.set_index(['ID'])

# %%
label_name = 'Calories_Burned'

X = train.drop(columns=label_name)
y = train[label_name]

# %%
cat_features = [] # 문자열 이기 때문에 넣어줌.  
target_col = 'Calories_Burned'

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7500 entries, TRAIN_0000 to TRAIN_7499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Exercise_Duration  7500 non-null   float64
#  1   Body_Temperature   7500 non-null   float64
#  2   BPM                7500 non-null   float64
#  3   Height             7500 non-null   float64
#  4   Weight             7500 non-null   float64
#  5   Weight_Status      7500 non-null   int32
#  6   Gender             7500 non-null   int32
#  7   Age                7500 non-null   int64
#  8   Calories_Burned    7500 non-null   float64
# dtypes: float64(6), int32(2), int64(1)
# memory usage: 527.3+ KB

# %%
from catboost import CatBoostRegressor
catb = CatBoostRegressor(
         cat_features=cat_features,
         loss_function='MAE',
         n_estimators=500, 
         learning_rate=0.05, 
         random_state=42
    )
    
catb.fit(train.drop(columns=[target_col]), train[target_col], verbose=100)
# Out:
# 0:	learn: 50.4069656	total: 155ms	remaining: 1m 17s
# 100:	learn: 2.7912882	total: 399ms	remaining: 1.58s
# 200:	learn: 1.6723527	total: 706ms	remaining: 1.05s
# 300:	learn: 1.1657402	total: 943ms	remaining: 624ms
# 400:	learn: 0.8999556	total: 1.15s	remaining: 284ms
# 499:	learn: 0.7535147	total: 1.37s	remaining: 0us

# %%
predict_y =  catb.predict(test)

# %%
predict_y[:5]
# Out:
# array([173.39495564, 189.1355516 ,  52.83109773, 158.505463  ,
#        227.40040859])

# %%
submit['Calories_Burned'] = predict_y
submit.head(2)
# Out:
#           ID  Calories_Burned
# 0  TEST_0000       173.394956
# 1  TEST_0001       189.135552

# %%
#submit.to_csv('./Calories.Cat.csv', index = False)
